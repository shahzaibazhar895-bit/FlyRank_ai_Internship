# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/shahzaibazhar895-bit/FlyRank_ai_Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# My Lane
#
#
# I chose Lane 2: Refresh / Content Opportunity Scoring.
#
# The goal of this lane is to identify pages that should be reviewed first for refresh, expansion, optimization, or monitoring. Since large content inventories cannot be reviewed manually, a ranking system can help prioritize pages based on observable signals such as impressions, CTR, freshness, and performance trends. I selected this lane because the starter dataset already contains relevant signals that can support evidence-based prioritization.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# Decision: bold textMy project aims to improve the decision of which content pages should be reviewed first for content refresh, expansion, monitoring, or improvement.
#
# Action: A content manager, SEO analyst, or website owner can use the ranked recommendations to prioritize pages that may have declining performance or missed opportunities.
#
# Cost of a wrong recommendation: If a page is incorrectly flagged as high priority, time and resources may be spent reviewing a page that does not need attention. If an important page is missed, a real opportunity for traffic growth or performance recovery could be overlooked. Therefore, the goal is to support better prioritization rather than guarantee outcomes.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# Quick Look at the Data
#
#
# The starter dataset contains 30,000 pages.
#
# Approximately 54.21% of pages are labeled as declining. This suggests that a substantial portion of the content inventory may require monitoring or review.
#
# The average CTR is 0.5107, indicating variation in page performance across the dataset.
#
# These observations suggest that prioritizing pages for review is a meaningful problem and support my choice of the Refresh / Content Opportunity Scoring lane.

# %%
# !git clone https://github.com/flyrank-bih/flyrank-ml-internship-starter
# Out:
# Cloning into 'flyrank-ml-internship-starter'...
# remote: Enumerating objects: 283, done.
# remote: Counting objects: 100% (145/145), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 283 (delta 112), reused 83 (delta 83), pack-reused 138 (from 1)
# Receiving objects: 100% (283/283), 1.85 MiB | 4.78 MiB/s, done.
# Resolving deltas: 100% (153/153), done.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv(
    "flyrank-ml-internship-starter/data/raw/content_refresh_anonymized.csv"
)

print("Total Pages:", len(df))

declining_rate = (df["trend_direction"].str.lower() == "down").mean()
print("Declining Rate:", round(declining_rate * 100, 2), "%")

print("Average CTR:", round(df["ctr"].mean(), 4))
# Out:
# Total Pages: 30000
# Declining Rate: 54.21 %
# Average CTR: 0.5107

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# What I Can and Cannot Claim
#
#
# This project can identify observed patterns and signals associated with pages that may deserve review or optimization.
#
# The results can provide decision-support recommendations by helping reviewers prioritize pages that appear to have refresh or improvement opportunities.
#
# The findings may suggest directional relationships between content signals and page performance, but they do not prove cause and effect.
#
# This project cannot prove that refreshing a page will improve traffic, clicks, or rankings.
#
# It also cannot predict search engine algorithms or explain exactly how search engines rank content. Any conclusions should be interpreted as observational and decision-support evidence rather than causal proof.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
